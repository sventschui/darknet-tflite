# %%
# !dpkg --print-architecture
# Out:
# amd64

# %%
# %pip install -r  /content/darknet_tflite/requirements.txt

# %%
# !cd /content/darknet_tflite/ && ls functions && python -m benchmark2
# Out:
# __init__.py	      postprocess_output.py  __pycache__
# parse_darknet_cfg.py  preprocess_image.py    visualize_detections.py
# Loading darknet...
# Allocating workspace:  4.9 MiB
# Loading ONNX model...
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# Image /content/darknet_tflite/benchmark2/images/DSCN2164_frame_000104.jpg
# AVX detected.
# FMA & AVX2 detected.
# \_ Darknet:            20ms   2 detections
#      \_ center         0.98
#      \_ medium gear    1.0
# \_ ONNX:               19ms   2 detections
#      \_ center         0.98
#      \_ medium gear    1.0
#
# \_ tflite_float32:     26ms   2 detections
#      \_ center         0.98
#      \_ medium gear    1.0
#
# \_ tflite_float16:     22ms   2 detections
#      \_ center         0.98
#      \_ medium gear    1.0
#
# \_ tflite_int:         20ms   2 detections
#      \_ center         0.98
#      \_ medium gear    0.99
#
# Image /content/darknet_tflite/benchmark2/images/DSCN2164_frame_000035.jpg
# ...

# %%
import onnxruntime as ort
print(ort.get_available_providers())
# Out:
# ['AzureExecutionProvider', 'CPUExecutionProvider']
